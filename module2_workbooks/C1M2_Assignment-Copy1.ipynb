# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    
    You are an Essay Writing Assistant for university students. You will be provided with an essay title and generate a first draft of the essay.
    
    Essay_Topic:
    {topic}
    
    Respond with a draft of the essay.
    """

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    
    You are a university dissertation assessor for final-year undergraduate submissions.
    
    Essay_Draft:
    {draft}
    
    Evaluate the draft against each rubric criterion below. For each criterion,
    assign a score from 1 (poor) to 5 (excellent).

    Rubric:
    1. argument_clarity   – The argument proposed in the draft is clear, specific,
                            and identifiable as a central thesis.
    2. evidence_quality   – The argument is supported with relevant, well-chosen
                            examples that strengthen the claims made.
    3. writing_style      – The writing style, tone, and academic register are
                            consistent with what is expected for a final-year
                            dissertation submission (formal language, appropriate
                            hedging, correct referencing conventions).

    After scoring, write a short "feedback" field: a constructive yet critical
    summary (3-6 sentences) that highlights the most important strengths and
    the most actionable areas for improvement.

    Return STRICT JSON with exactly these fields:
    {{
      "argument_clarity": <int 1-5>,
      "evidence_quality": <int 1-5>,
      "writing_style": <int 1-5>,
      "feedback": "<constructive critical summary>"
    }}
    
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###
    
    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    
    You are a final year student making changes to an essay following reflection from an Essay Draft Reviewer.
    
    Original_Draft:
    {original_draft}
    
    Reflection:
    {reflection}
    
    Return a STRICT JSON object containing the fields:
    {{
        "feedback": A summary of the feedback from the reflection.
        "revised_draft": An updated draft based on feedback from the reflection.
    }}
    
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: Should Social Media Platforms Be Regulated by the Government?
#
# Introduction
#
# In the digital age, social media has become an indispensable part of our daily lives, shaping how we communicate, share information, and perceive the world. Platforms like Facebook, Twitter, Instagram, and TikTok have expanded the horizons of communication, fostering global connections and democratizing information dissemination. However, this unprecedented power also raises pertinent questions about privacy, misinformation, and the influence of social media on public discourse. Consequently, there is growing debate over whether government regulation of social media platforms is necessary to safeguard public interest. This essay will explore the arguments for and against government regulation and offer suggestions for a balanced approach to managing social media's influence.
#
# Arguments for Government Regulation
#
# One of the most compelling arguments for government regulation of social media platforms is the need to curb the spread of misinformation and fake news. Misinformation can have dire consequences, such as influencing electoral outcomes, spreading false health information, or exacerbating societal divides. The rapid dissemination of false information during the COVID-19 pandemic, for instance, highlighted the urgent need for effective regulatory measures to prevent the spread of harmful content. Governments can impose regulations to ensure social media companies take responsibility for monitoring content dissemination and preventing false information from gaining traction.
#
# Another concern is the protection of user privacy. Social media platforms collect vast amounts of personal data, which can be exploited for commercial purposes or fall prey to malicious actors. Recent scandals, such as the Cambridge Analytica incident, have demonstrated how personal data can be misused for political manipulation and commercial gain. Government regulations could establish clear guidelines on data privacy and establish accountability frameworks to ensure social media companies uphold their responsibilities to protect user information.
#
# Furthermore, there is a need to address the monopolistic tendencies of major social media platforms. A few companies dominating the landscape can stifle competition and innovation, leading to reduced consumer choice and potential misuse of power. Government intervention can foster a competitive environment by ensuring fair play, creating opportunities for new entrants, and limiting the dominance of major tech companies, thus promoting a healthier digital ecosystem.
#
# Arguments Against Government Regulation
#
# Conversely, opponents of government regulation argue that such measures could stifle free speech and limit the open democratic exchange of ideas that social media facilitates. Social media platforms serve as modern public squares, where individuals can express diverse viewpoints and engage in robust debate. Heavy-handed regulation could lead to censorship, where governments, intentionally or otherwise, suppress dissenting voices and unpopular opinions, undermining democratic principles.
#
# Additionally, government regulation may struggle to keep pace with the rapidly evolving nature of technology and digital communication. Bureaucratic processes might be too slow to respond to the dynamic nature of social media platforms, leading to outdated regulations that fail to address new challenges effectively. A one-size-fits-all regulatory framework may not account for the nuanced differences between platforms, inhibiting innovation and adaptation to emerging trends and technologies.
#
# Another concern is the potential for regulatory capture, wherein powerful social media companies may exert undue influence on the regulatory process, leading to policies that favor industry giants over consumers. This could result in regulations that entrench the power of existing players and stifle competition, rather than promoting a fair and open digital market.
#
# A Balanced Approach
#
# To strike a balance between maintaining free speech and protecting public interest, a collaborative approach involving governments, social media companies, and civil society could be beneficial. Co-regulation, where governments set overarching guidelines and social media platforms develop specific policies, may offer a more flexible and effective solution. This approach allows platforms to innovate while adhering to shared norms and standards of conduct.
#
# Voluntary industry codes of conduct, transparency initiatives, and third-party audits can complement government efforts, promoting best practices and accountability in content moderation and data privacy. Education and media literacy programs can empower users to navigate the digital landscape critically, reducing the impact of misinformation and enhancing digital citizenship.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government involves complex considerations of free speech, privacy, innovation, and public welfare. While there are compelling reasons for intervention to address issues such as misinformation and data privacy, it is crucial to ensure that any regulatory measures do not stifle free expression or innovation. A balanced, collaborative approach that involves stakeholders from various sectors can help in crafting effective regulations that promote a healthy, open, and equitable digital environment. As social media continues to evolve, ongoing dialogue and adaptation will be key to ensuring these platforms benefit society as a whole.
#
# 🧠 Feedback:
#
# {"argument_clarity":4,"evidence_quality":3,"writing_style":3,"feedback":"The draft presents a clear and balanced central thesis on the pros and cons of government regulation of social media. It effectively uses timely examples such as COVID-19 misinformation and the Cambridge Analytica scandal, though these examples remain underdeveloped and would benefit from deeper empirical data or scholarly references. The structure is logical, but the treatment of opposing views and the proposed co-regulatory model could be expanded with more nuanced analysis. The writing is formal and consistent, yet it lacks in-text citations, hedging language, and the rigorous referencing expected at the dissertation level. To strengthen this draft, the author should integrate peer-reviewed sources, provide more detailed case studies, and adopt a more scholarly tone with proper citation conventions."}
#
# ✍️ Revised:
#
# ```json
# {
#     "feedback": "The draft presents a balanced view on government regulation of social media, effectively using examples like COVID-19 misinformation and the Cambridge Analytica scandal. However, these examples need more empirical data or scholarly references. The structure is logical, but opposing views and the co-regulatory model require more nuanced analysis. The writing is formal and consistent but lacks in-text citations, hedging language, and rigorous referencing. To strengthen the draft, integrate peer-reviewed sources, provide detailed case studies, and adopt a scholarly tone with proper citations.",
#     "revised_draft": "Title: Should Social Media Platforms Be Regulated by the Government? \n\nIntroduction \n\nIn the digital age, social media has become an indispensable part of our daily lives, shaping how we communicate, share information, and perceive the world. Platforms like Facebook, Twitter, Instagram, and TikTok have expanded the horizons of communication, fostering global connections and democratizing information dissemination. However, this unprecedented power also raises pertinent questions about privacy, misinformation, and the influence of social media on public discourse. Consequently, there is growing debate over whether government regulation of social media platforms is necessary to safeguard public interest. This essay will explore the arguments for and against government regulation and offer suggestions for a balanced approach to managing social media's influence.\n\nArguments for Government Regulation\n\nOne compelling argument for government regulation of social media platforms is the need to curb the spread of misinformation and fake news. Empirical studies indicate that misinformation can influence electoral outcomes, spread false health information, and exacerbate societal divides (Lazer et al., 2018). The rapid dissemination of false information during the COVID-19 pandemic, as documented by Pennycook et al. (2020), highlighted the urgent need for effective regulatory measures. By implementing regulations, governments can compel social media companies to take responsibility for monitoring content dissemination and preventing false information from gaining traction.\n\nAnother concern is the protection of user privacy. Social media platforms collect vast amounts of personal data, which can be exploited for commercial purposes or fall prey to malicious actors. Scandals like Cambridge Analytica have demonstrated how personal data can be misused for political manipulation and commercial gain (Isaak & Hanna, 2018). Government regulations could establish clear guidelines on data privacy and establish accountability frameworks to ensure social media companies uphold their responsibilities to protect user information.\n\nFurthermore, there is a need to address the monopolistic tendencies of major social media platforms. A few companies dominating the landscape can stifle competition and innovation, leading to reduced consumer choice and potential misuse of power. Government intervention can foster a competitive environment by ensuring fair play, creating opportunities for new entrants, and limiting the dominance of major tech companies, thus promoting a healthier digital ecosystem.\n\nArguments Against Government Regulation\n\nConversely, opponents of government regulation argue that such measures could stifle free speech and limit the open democratic exchange of ideas that social media facilitates. As noted by Sunstein (2018), social media platforms serve as modern public squares, where individuals can express diverse viewpoints and engage in robust debate. Heavy-handed regulation could lead to censorship, where governments, intentionally or otherwise, suppress dissenting voices and unpopular opinions, thus undermining democratic principles.\n\nAdditionally, government regulation may struggle to keep pace with the rapidly evolving nature of technology and digital communication. Bureaucratic processes might be too slow to respond to the dynamic nature of social media platforms, leading to outdated regulations that fail to address new challenges effectively (Balkin, 2017). A one-size-fits-all regulatory framework may not account for the nuanced differences between platforms, inhibiting innovation and adaptation to emerging trends and technologies.\n\nAnother concern is the potential for regulatory capture, wherein powerful social media companies may exert undue influence on the regulatory process, leading to policies that favor industry giants over consumers. This could result in regulations that entrench the ...
# }
# ```

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Should Social Media Platforms Be Regulated by the Government?
#
# Introduction
#
# In the digital age, social media has become an indispensable part of our daily lives, shaping how we communicate, share information, and perceive the world. Platforms like Facebook, Twitter, Instagram, and TikTok have expanded the horizons of communication, fostering global connections and democratizing information dissemination. However, this unprecedented power also raises pertinent questions about privacy, misinformation, and the influence of social media on public discourse. Consequently, there is growing debate over whether government regulation of social media platforms is necessary to safeguard public interest. This essay will explore the arguments for and against government regulation and offer suggestions for a balanced approach to managing social media's influence.
#
# Arguments for Government Regulation
#
# One of the most compelling arguments for government regulation of social media platforms is the need to curb the spread of misinformation and fake news. Misinformation can have dire consequences, such as influencing electoral outcomes, spreading false health information, or exacerbating societal divides. The rapid dissemination of false information during the COVID-19 pandemic, for instance, highlighted the urgent need for effective regulatory measures to prevent the spread of harmful content. Governments can impose regulations to ensure social media companies take responsibility for monitoring content dissemination and preventing false information from gaining traction.
#
# Another concern is the protection of user privacy. Social media platforms collect vast amounts of personal data, which can be exploited for commercial purposes or fall prey to malicious actors. Recent scandals, such as the Cambridge Analytica incident, have demonstrated how personal data can be misused for political manipulation and commercial gain. Government regulations could establish clear guidelines on data privacy and establish accountability frameworks to ensure social media companies uphold their responsibilities to protect user information.
#
# Furthermore, there is a need to address the monopolistic tendencies of major social media platforms. A few companies dominating the landscape can stifle competition and innovation, leading to reduced consumer choice and potential misuse of power. Government intervention can foster a competitive environment by ensuring fair play, creating opportunities for new entrants, and limiting the dominance of major tech companies, thus promoting a healthier digital ecosystem.
#
# Arguments Against Government Regulation
#
# Conversely, opponents of government regulation argue that such measures could stifle free speech and limit the open democratic exchange of ideas that social media facilitates. Social media platforms serve as modern public squares, where individuals can express diverse viewpoints and engage in robust debate. Heavy-handed regulation could lead to censorship, where governments, intentionally or otherwise, suppress dissenting voices and unpopular opinions, undermining democratic principles.
#
# Additionally, government regulation may struggle to keep pace with the rapidly evolving nature of technology and digital communication. Bureaucratic processes might be too slow to respond to the dynamic nature of social media platforms, leading to outdated regulations that fail to address new challenges effectively. A one-size-fits-all regulatory framework may not account for the nuanced differences between platforms, inhibiting innovation and adaptation to emerging trends and technologies.
#
# Another concern is the potential for regulatory capture, wherein powerful social media companies may exert undue influence on the regulatory process, leading to policies that favor industry giants over consumers. This could result in regulations that entrench the power of existing players and stifle competition, rather than promoting a fair and open digital market.
#
# A Balanced Approach
#
# To strike a balance between maintaining free speech and protecting public interest, a collaborative approach involving governments, social media companies, and civil society could be beneficial. Co-regulation, where governments set overarching guidelines and social media platforms develop specific policies, may offer a more flexible and effective solution. This approach allows platforms to innovate while adhering to shared norms and standards of conduct.
#
# Voluntary industry codes of conduct, transparency initiatives, and third-party audits can complement government efforts, promoting best practices and accountability in content moderation and data privacy. Education and media literacy programs can empower users to navigate the digital landscape critically, reducing the impact of misinformation and enhancing digital citizenship.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government involves complex considerations of free speech, privacy, innovation, and public welfare. While there are compelling reasons for intervention to address issues such as misinformation and data privacy, it is crucial to ensure that any regulatory measures do not stifle free expression or innovation. A balanced, collaborative approach that involves stakeholders from various sectors can help in crafting effective regulations that promote a healthy, open, and equitable digital environment. As social media continues to evolve, ongoing dialogue and adaptation will be key to ensuring these platforms benefit society as a whole.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">{"argument_clarity":4,"evidence_quality":3,"writing_style":3,"feedback":"The draft presents a clear and balanced central thesis on the pros and cons of government regulation of social media. It effectively uses timely examples such as COVID-19 misinformation and the Cambridge Analytica scandal, though these examples remain underdeveloped and would benefit from deeper empirical data or scholarly references. The structure is logical, but the treatment of opposing views and the proposed co-regulatory model could be expanded with more nuanced analysis. The writing is formal and consistent, yet it lacks in-text citations, hedging language, and the rigorous referencing expected at the dissertation level. To strengthen this draft, the author should integrate peer-reviewed sources, provide more detailed case studies, and adopt a more scholarly tone with proper citation conventions."}</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">```json
# {
#     "feedback": "The draft presents a balanced view on government regulation of social media, effectively using examples like COVID-19 misinformation and the Cambridge Analytica scandal. However, these examples need more empirical data or scholarly references. The structure is logical, but opposing views and the co-regulatory model require more nuanced analysis. The writing is formal and consistent but lacks in-text citations, hedging language, and rigorous referencing. To strengthen the draft, integrate peer-reviewed sources, provide detailed case studies, and adopt a scholarly tone with proper citations.",
#     "revised_draft": "Title: Should Social Media Platforms Be Regulated by the Government? \n\nIntroduction \n\nIn the digital age, social media has become an indispensable part of our daily lives, shaping how we communicate, share information, and perceive the world. Platforms like Facebook, Twitter, Instagram, and TikTok have expanded the horizons of communication, fostering global connections and democratizing information dissemination. However, this unprecedented power also raises pertinent questions about privacy, misinformation, and the influence of social media on public discourse. Consequently, there is growing debate over whether government regulation of social media platforms is necessary to safeguard public interest. This essay will explore the arguments for and against government regulation and offer suggestions for a balanced approach to managing social media's influence.\n\nArguments for Government Regulation\n\nOne compelling argument for government regulation of social media platforms is the need to curb the spread of misinformation and fake news. Empirical studies indicate that misinformation can influence electoral outcomes, spread false health information, and exacerbate societal divides (Lazer et al., 2018). The rapid dissemination of false information during the COVID-19 pandemic, as documented by Pennycook et al. (2020), highlighted the urgent need for effective regulatory measures. By implementing regulations, governments can compel social media companies to take responsibility for monitoring content dissemination and preventing false information from gaining traction.\n\nAnother concern is the protection of user privacy. Social media platforms collect vast amounts of personal data, which can be exploited for commercial purposes or fall prey to malicious actors. Scandals like Cambridge Analytica have demonstrated how personal data can be misused for political manipulation and commercial gain (Isaak & Hanna, 2018). Government regulations could establish clear guidelines on data privacy and establish accountability frameworks to ensure social media companies uphold their responsibilities to protect user information.\n\nFurthermore, there is a need to address the monopolistic tendencies of major social media platforms. A few companies dominating the landscape can stifle competition and innovation, leading to reduced consumer choice and potential misuse of power. Government intervention can foster a competitive environment by ensuring fair play, creating opportunities for new entrants, and limiting the dominance of major tech companies, thus promoting a healthier digital ecosystem.\n\nArguments Against Government Regulation\n\nConversely, opponents of government regulation argue that such measures could stifle free speech and limit the open democratic exchange of ideas that social media facilitates. As noted by Sunstein (2018), social media platforms serve as modern public squares, where individuals can express diverse viewpoints and engage in robust debate. Heavy-handed regulation could lead to censorship, where governments, intentionally or otherwise, suppress dissenting voices and unpopular opinions, thus undermining democratic principles.\n\nAdditionally, government regulation may struggle to keep pace with the rapidly evolving nature of technology and digital communication. Bureaucratic processes might be too slow to respond to the dynamic nature of social media platforms, leading to outdated regulations that fail to address new challenges effectively (Balkin, 2017). A one-size-fits-all regulatory framework may not account for the nuanced differences between platforms, inhibiting innovation and adaptation to emerging trends and technologies.\n\nAnother concern is the potential for regulatory capture, wherein powerful social media companies may exert undue influence on the regulatory process, leading to policies that favor industry giants over consumers. This could result in regulations that entrench the ...
# }
# ```</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
